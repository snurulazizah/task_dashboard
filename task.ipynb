# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import requests
from datetime import datetime, timedelta
from pandas import json_normalize

# %%
API_TOKEN = "62f2723b77ca522759653544007fedcf40e24a8f0f405aeaba9f65984dc6134e"

# %%
url = "https://crm.qontak.com/api/v3.1/tasks?filter=alltask&page=1&per_page=100"
headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Accept": "application/json"
}

response = requests.get(url, headers=headers)
    
data = response.json()
df = pd.json_normalize(data['response'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\MY ASUS\anaconda3\envs\dss_airflow\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\MY ASUS\anaconda3\envs\dss_airflow\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\MY ASUS\anaconda3\envs\dss_airflow\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\MY ASUS\anaconda3\envs\dss_airflow\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 9
#       2 headers = {
#       3     "Authorization": f"Bearer {API_TOKEN}",
#       4     "Accept": "application/json"
#       5 }
#       7 response = requests.get(url, headers=headers)
# ----> 9 data = response.json()
#      10 df = pd.json_normalize(data['response'])
#
# File c:\Users\MY ASUS\anaconda3\envs\dss_airflow\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data
# Out:
# {}
